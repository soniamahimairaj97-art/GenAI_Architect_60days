# %%
a=10
b=20
c=a+b
print(c)
# Out:
# 30

# %%
file=open("note.txt","r")
content=file.read()
print(content)
# Out:
# Content Changed

# %%
file=open("note.txt","w")
file.write("Content Changed")
file.close()
print(content)
# Out:
# 15

# %%
file=open("note.txt","a")
file.write("\n content added newly \n")
file.write("\n second line \n")
file.close()

# %%
with open("note.txt","r") as file:
 content=file.read()
 print(content)
# Out:
# Content Changed
#
#  content added newly
#
#  second line

# %%
import os 

os.getcwd()
# Out:
# 'c:\\Users\\sonia\\OneDrive\\Desktop\\PythonDays'

# %%
os.mkdir("Python Test Practice")

# %%
os.listdir()
# Out:
# ['Day1.py',
#  'Day10.py',
#  'Day2.py',
#  'Day3.py',
#  'Day4.py',
#  'Day5.py',
#  'Day6.py',
#  'Day7.py',
#  'Day8.py',
#  'Day9.py',
#  'Excercise1.py',
#  'Excercise2.py',
#  'Excercise3.py',
#  'Excercise4.py',
#  'Excercise5.py',
#  'Excercise6.py',
#  'Excercise7.py',
#  'first.ipynb',
#  'Heart.py',
#  'note.txt',
#  'Python Test Practice',
#  'PythonPractice']
